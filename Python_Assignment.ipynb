# %% [markdown]
# <a href="https://colab.research.google.com/github/HyunsukLee/YonseiAMBA-Business-Data-Analysis-Methodology/blob/main/Python_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Assignment (Use the file "Purchase_Data.csv" )

# %%
#아래코드는 연세대학교 경영정보대학원 AMBA 과정 중
#경영데이터 분석 방법론 수업의 개인과제이다.
#AMBA 2기 이현석 의 개인 과제임을 표시합니다.

# %% [markdown]
# Compute the average and max price charged.  Store the results in variables called avg_price and max_price
#
# 평균 가격과 최대 가격을 계산하십시오.
# 결과를 avg_price 및 max_price 변수에 저장하십시오.

# %%
#Write your code here
import pandas as pd
df_data = pd.read_csv("/content/sample_data/Purchase_Data.csv")

totalPrice = sum(df_data.price)
cntPrice = len(df_data.price)

avg_price  = totalPrice / cntPrice  #평균가격
max_price = max(df_data.price)      #최대가격

print("mean 메소드를 이용한 평균 : ", df_data['price'].mean() )
print("avg_price : ", avg_price)
print("max_price : ", max_price)

# %% [markdown]
# Compute the average price and average number of items purchased with only a single call to the mean() method. Store these averages in avg_price and avg_num_items.
#
# mean() 메서드를 한 번만 호출하여 평균 가격과 평균 구매 품목 수를 계산하십시오. 이 평균값을 avg_price 및 avg_num_items 변수에 저장하십시오.

# %%
#Write you code here

#avg_price      평균 가격
#avg_num_items  평균 구매 품목 수
avg_price, avg_num_items = df_data[['price', 'num_item']].mean()

print("avg_price : " , avg_price)
print("avg_num_items : " , avg_num_items)
# Out:
# avg_price :  3.1920522110741363
# avg_num_items :  1.2983091787439613

# %% [markdown]
# Create a column called "total", which is the product of the price and num_item columns.
#
# ‘price’ 열과 ‘num_item’ 열을 곱하여 'total'이라는 열을 생성하십시오.

# %%
#Write your code here
df_data['total'] = df_data['price'] * df_data['num_item']
df_data.head()
# Out:
#    invoice_number   invoice_time store_id  product_id  category_id  num_item  \
# 0    2.020000e+11  7/15/15 10:45     G816     7000300       210101       1.0
# 1    2.020000e+11  7/15/15 12:16     G816     7070884        70203       1.0
# 2    2.020000e+11  7/15/15 12:16     G816     7070884        70203       1.0
# 3    2.020000e+11  7/15/15 12:16     G816     7070891        70401       1.0
# 4    2.020000e+11  7/15/15 12:16     G816     7090363        70401       1.0
#
#    price  total
# 0    2.0    2.0
# 1    2.0    2.0
# 2    2.0    2.0
# 3    6.0    6.0
# 4    6.0    6.0

# %% [markdown]
# Find the difference between the mean and median of the column total.  Use the describe() method and then index the dataframe it returns.
#
# 열 합계의 평균과 중앙값 사이의 차이를 구하세요.
# describe() 메서드를 사용한 후 반환된 데이터프레임의 인덱스를 지정하세요.

# %%
#total 컬럼의 평균과 중앙값 사이의 차
diff = df_data["total"].mean() - df_data["total"].median()
print("total 컬럼의 평균과 중앙값 사이의 차 : ", diff)

#describe() 메서드를 사용 한 후 인덱스 지정 후 평균과 중앙값 사이의 차이
status = df_data["total"].describe()
status
meanTotal = status["mean"]
medianTotal = status["50%"]

print("describe() 메서드를 사용 한 후 인덱스 지정 후 평균과 중앙값 사이의 차이 : ", meanTotal - medianTotal)
# Out:
# total 컬럼의 평균과 중앙값 사이의 차 :  0.9318078781127839
# describe() 메서드를 사용 한 후 인덱스 지정 후 평균과 중앙값 사이의 차이 :  0.9318078781127839

# %% [markdown]
# How many different products are there?
#
# 얼마나 많은 종류의 제품이 있나요?

# %%
uniq_product = df_data["product_id"].nunique()
print("제품의 종류는 ", uniq_product, " 가지 입니다")
# Out:
# 제품의 종류는  53  가지 입니다

# %% [markdown]
# What is the avgerage price of the three most expensive purchases?
#
# 가장 비싼 세 가지 구매 항목의 평균 가격은 얼마입니까?
#
# ---

# %%
#Write your code here
n=3     #nlargest 변수 값
top3 = df_data.nlargest(n, "price", keep="first")
avg_price_top3 = top3["price"].mean()

print("Average price of top 3 purchases:", avg_price_top3)
top3
# Out:
# Average price of top 3 purchases: 6.003333333333333
#       invoice_number   invoice_time store_id  product_id  category_id  \
# 2979    2.020000e+11  8/21/15 12:14     6666     7070969        70401
# 3       2.020000e+11  7/15/15 12:16     G816     7070891        70401
# 4       2.020000e+11  7/15/15 12:16     G816     7090363        70401
#
#       num_item  price  total
# 2979       3.0   6.01  18.03
# 3          1.0   6.00   6.00
# 4          1.0   6.00   6.00

# %% [markdown]
# Use the drop() method to delete the column total from the dataframe df_data.
#
# drop() 메서드를 사용하여 데이터프레임 df_data에서 열 합계(total 컬럼)를 삭제하십시오.

# %%
#Write your code here
df_data.drop("total", axis=1, inplace=True)
df_data.head()
# Out:
#    invoice_number   invoice_time store_id  product_id  category_id  num_item  \
# 0    2.020000e+11  7/15/15 10:45     G816     7000300       210101       1.0
# 1    2.020000e+11  7/15/15 12:16     G816     7070884        70203       1.0
# 2    2.020000e+11  7/15/15 12:16     G816     7070884        70203       1.0
# 3    2.020000e+11  7/15/15 12:16     G816     7070891        70401       1.0
# 4    2.020000e+11  7/15/15 12:16     G816     7090363        70401       1.0
#
#    price
# 0    2.0
# 1    2.0
# 2    2.0
# 3    6.0
# 4    6.0

# %% [markdown]
# Let's dig a little deeper into the data set and answer some basic question.
#
# 데이터 세트를 좀 더 깊이 살펴보고 기본적인 질문에 답해 보겠습니다.

# %% [markdown]
# First, covert the column invoice time to a datetime column. Print out the new column types to make sure this was done correctly
#
# 먼저, invoice time 열을 날짜/시간 열로 변환하세요. 새 열의 데이터 유형을 출력하여 변환이 올바르게 수행되었는지 확인하세요.

# %%
#Write your code here
df_data["invoice_time"] = pd.to_datetime(df_data["invoice_time"])
print(df_data.dtypes)
# Out:
# invoice_number           float64
# invoice_time      datetime64[ns]
# store_id                  object
# product_id                 int64
# category_id                int64
# num_item                 float64
# price                    float64
# dtype: object

# %% [markdown]
# Next, let's create columns called "DOW" and "Month", which store the corresponding weekday and month of the invoice respectively.  Print the head of the dataframe to make sure this was done correctly.
#
# 다음으로, 각각 해당 청구서의 요일과 월을 저장하는 “DOW”와 “Month”라는 열을 생성합니다. 데이터프레임의 헤더를 출력하여 이 작업이 올바르게 수행되었는지 확인합니다.

# %%
df_data["DOW"] = df_data["invoice_time"].dt.day_name()
df_data["Month"] = df_data["invoice_time"].dt.month_name()
df_data.head()
# Out:
#    invoice_number        invoice_time store_id  product_id  category_id  \
# 0    2.020000e+11 2015-07-15 10:45:00     G816     7000300       210101
# 1    2.020000e+11 2015-07-15 12:16:00     G816     7070884        70203
# 2    2.020000e+11 2015-07-15 12:16:00     G816     7070884        70203
# 3    2.020000e+11 2015-07-15 12:16:00     G816     7070891        70401
# 4    2.020000e+11 2015-07-15 12:16:00     G816     7090363        70401
#
#    num_item  price        DOW Month
# 0       1.0    2.0  Wednesday  July
# 1       1.0    2.0  Wednesday  July
# 2       1.0    2.0  Wednesday  July
# 3       1.0    6.0  Wednesday  July
# 4       1.0    6.0  Wednesday  July

# %% [markdown]
# Create a variable called num_purchases_wed, which stores the number of purchases made on Wednesday?  You should use value_counts and then index the series it return.
#
# 수요일 구매 건수를 저장하는 num_purchases_wed 변수를 생성하세요. value_counts 함수를 사용한 후 반환된 시리즈를 인덱싱해야 합니다.

# %%
num_purchases_wed = df_data["DOW"].value_counts()["Wednesday"]
print("Number of purchases on Wednesday:", num_purchases_wed)
# Out:
# Number of purchases on Wednesday: 959
